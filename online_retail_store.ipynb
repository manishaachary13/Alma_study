# %% [markdown]
# <a href="https://colab.research.google.com/github/manishaachary13/Alma_study/blob/main/online_retail_store.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Online Retail Store![retailERD.pgerd.png](data:image/png;base64,...![retailERD.png](data:image/png;base64,...))

# %% [markdown]
# This is the project for Online Retail Store. This Project stores information of Retail Store product sales information as well as customers informations.
# This project contains the database schema for this store, and also an ERD for the database.

# %% [markdown]
# Designing a database schema for the given scenario involves identifying the entities, their attributes, and the relationships between them.
# The main entities are:
#
#
# 1.   Customers: Contains information about the store customers.
#
#
# *   Customer_id(Primary Key): Unique identifier for each customer.
# *   FirstName: First name of customer.
# *   LastName: Last name of customer.
# *   Email: Email address of customer.
# *   Phone: Phone number of customer.
#
#
# 2.   Products: Contains product details of retail store.
# *   Product_id(Primary Key): Unique ID of each product.
# *   ProductName: Title of the product.
# *   Description: Additional detailed information about product.
# *   Category: The category of product.
# *   Price: Price of product.
#
# 3.   Orders: Contains the order information including the customer who placed the order.
# *   OrderID(Primary Key): Unique order id.
# *   CustomerID(Foreign Key): References the Customer table to link the order to the customer who placed it.
# *   OrderDate: Date on which the order was placed.
# *   ShipDate: Date on which the order was shipped.
# *   TotalAmount:The total amount of each order.
#
# 4.   OrderDeatils:  Contains information about the products included in each order.
# *   OrderID(Foreign Key): References the Order table to link the order item to its corresponding order.
# *   ProductID(Foreign Key): References the Products table to link the order item to the specific product it represents.
# *   Quantity: The number of product ordered.
# *   Price:The price of the product at the time of the orer placed.

# %% [markdown]
# Here's the ERD(Entity-Relationship Diagram) for Online Retail Store Database.

# %% [markdown]
# ![my_picture](https://github.com/manishaachary13/Alma_study/blob/main/retailERD.png?raw=trueretailERD.png)

# %% [markdown]
# Task 1: Upload the tables in a database in SQL .And also describe what you understood of the tables .
#
#
# ```
#
# CREATE TABLE Customers (
#     CustomerID INT PRIMARY KEY,
#     FirstName VARCHAR(50),
#     LastName VARCHAR(50),
#     Email VARCHAR(50),
#     Phone VARCHAR(20)
# );
#
# CREATE TABLE Products (
#     ProductID INT PRIMARY KEY,
#     ProductName VARCHAR(50),
#     Description TEXT,
#     Category VARCHAR(50),
#     Price DECIMAL(10,2)
# );
#
# CREATE TABLE Orders (
#     OrderID INT PRIMARY KEY,
#     CustomerID INT,
#     OrderDate DATE,
#     ShipDate DATE,
#     TotalAmount DECIMAL(10,2),
#     FOREIGN KEY (CustomerID) REFERENCES Customers(CustomerID)
# );
#
# CREATE TABLE OrderDetails (
#     OrderID INT,
#     ProductID INT,
#     Quantity INT,
#     Price DECIMAL(10,2),
#     FOREIGN KEY (OrderID) REFERENCES Orders(OrderID),
#     FOREIGN KEY (ProductID) REFERENCES Products(ProductID)
# );
#
# -- Insert sample data
# INSERT INTO Customers (CustomerID, FirstName, LastName, Email, Phone) VALUES
# (1, 'John', 'Doe', 'johndoe@example.com', '555-1234'),
# (2, 'Jane', 'Smith', 'janesmith@example.com', '555-5678'),
# (3, 'Bob', 'Johnson', 'bobjohnson@example.com', '555-9012');
#
# INSERT INTO Products (ProductID, ProductName, Description, Category, Price) VALUES
# (1, 'Product A', 'This is product A', 'Category 1', 10.00),
# (2, 'Product B', 'This is product B', 'Category 1', 20.00),
# (3, 'Product C', 'This is product C', 'Category 2', 30.00),
# (4, 'Product D', 'This is product D', 'Category 2', 40.00),
# (5, 'Product E', 'This is product E', 'Category 3', 50.00);
#
# INSERT INTO Orders (OrderID, CustomerID, OrderDate, ShipDate, TotalAmount) VALUES
# (1, 1, '2022-01-01', '2022-01-05', 50.00),
# (2, 2, '2022-01-02', '2022-01-06', 70.00),
# (3, 3, '2022-01-03', '2022-01-07', 90.00);
#
# INSERT INTO OrderDetails (OrderID, ProductID, Quantity, Price) VALUES
# (1, 1, 2, 10.00),
# (1, 3, 1, 30.00),
# (2, 2, 3, 20.00),
# (2, 4, 2, 40.00),
# (3, 1, 1, 10.00),
# (3, 2, 2, 20.00),
# (3, 3, 1, 30.00),
# (3, 4, 1, 40.00),
# (3, 5, 1, 50.00);
# ```

# %% [markdown]
# Task 2:
# Display the orders by each customer .
# ![image1](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Fcf8bf085-1402-4663-9108-51662503cc17%2FUntitled.png?table=block&id=88e1e970-7d47-4bce-816c-bfc2196c4b90&cache=v2)

# %% [markdown]
# Task 3:
# Ensure that all the emails of the customers are unique.
# ![image2](https://www.notion.so/image/https%3A%2F%2Fs3-us-west-2.amazonaws.com%2Fsecure.notion-static.com%2Fbca93a49-b95a-4f91-afd7-502ae168f16a%2FUntitled.png?table=block&id=0d2abb29-cdc4-4a17-a660-cdc57a539d42&cache=v2)
